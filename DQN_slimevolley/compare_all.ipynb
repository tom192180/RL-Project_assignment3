# %%
import pickle
import matplotlib.pyplot as plt

# %% [markdown]
# # Training results

# %%
with open('NEW_NDQN_batch_size.pickle', 'rb') as handle:
    NDQN = pickle.load(handle)

# %%
with open('NEW_DDQN_discretization_batch_size.pickle', 'rb') as handle:
    DDQN_dist = pickle.load(handle)

# %%
with open('NEW_DuelingDDQN_batch_size.pickle', 'rb') as handle:
    Duel_DDQN = pickle.load(handle)

# %%
with open('NEW_DuelingDDQN_discretization_batch_size.pickle', 'rb') as handle:
    Duel_DDQN_dist = pickle.load(handle)

# %%
#print(len(NDQN),len(Duel_DDQN),len(Duel_DDQN_dist))
print(NDQN[-1],DDQN_dist[-1],Duel_DDQN[-1],Duel_DDQN_dist[-1]) # timesteps taken
# Out:
# 1995217 2063385 3818573 3780852

# %%
plt.plot(NDQN[:-1])
plt.xlabel("Episode Number")
plt.ylabel("Reward")
plt.ylim([-5, 5])
# Out:
# (-5.0, 5.0)

# %%
plt.plot(DDQN_dist[:-1])
plt.xlabel("Episode Number")
plt.ylabel("Reward")
plt.ylim([-5, 5])
# Out:
# (-5.0, 5.0)

# %%
plt.plot(Duel_DDQN[:3500])
plt.xlabel("Episode Number")
plt.ylabel("Reward")
plt.ylim([-5, 5])
# Out:
# (-5.0, 5.0)

# %%
plt.plot(Duel_DDQN_dist[:3500])
plt.xlabel("Episode Number")
plt.ylabel("Reward")
plt.ylim([-5, 5])
# Out:
# (-5.0, 5.0)

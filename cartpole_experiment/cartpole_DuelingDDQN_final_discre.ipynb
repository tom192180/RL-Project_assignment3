# %% [markdown]
# # DuelingDDQN_discrete

# %% [markdown]
# I lernt from the following websites to finish the implementations.
# Reference:
# 1. Hung-yi Lee. DRL Lecture 3: Q-learning (Basic Idea)
# https://youtu.be/o_g9JUMw1Oc
# 2. Hung-yi Lee. DRL Lecture 4: Q-learning (Advanced Tips)
# https://www.youtube.com/watch?v=2-zGCx4iv_k&t=980s
# 3. Tensorflow
# https://www.tensorflow.org/api_docs/python/tf/keras/Model
# 4. Tom. Let's build a DQN: simple implementation
# https://tomroth.com.au/dqn-simple/
# 5. Reinforcement Learning tutorial
# https://pylessons.com/CartPole-DDDQN/

# %%
import gym
import numpy as np
import matplotlib.pyplot as plt 
# %matplotlib inline
import tensorflow as tf
from random import sample
import copy
# Setting up the environment 
env = gym.make("CartPole-v0")

# %%
def discretizaion(obs,bins = [30,30,30,30]):
    
    # the function map the currentstate into corrsponded discretized state
    
    #args
    # currentstate: np array.Include Cart Position, Cart Velocity, Pole Angle and Pole Angular Velocity.
    # bins:  List. How many bins we split for the 4 elements above.
    obs_copy = copy.deepcopy(obs)

    lower_bound = env.observation_space.low # Lowerbouund 
    lower_bound[[1,3]] = -5
    higher_bound = env.observation_space.high # Upper bound 
    higher_bound[[1,3]] = 5

    interval_length = (higher_bound - lower_bound)/np.array(bins)
    for i in range(len(obs_copy)):
      if obs_copy[i] <= lower_bound[i]:
          obs_copy[i] = lower_bound[i] + 0.000001
      elif obs_copy[i] > higher_bound[i]:
          obs_copy[i] =  higher_bound[i]

    coordinate  =(obs_copy - lower_bound)/interval_length
    return (np.ceil(coordinate)-1)

# %%
def create_model(name):
    input_layer = tf.keras.Input(shape = (4,))
    H1 = tf.keras.layers.Dense(32, activation='relu')(input_layer)
    H3 = tf.keras.layers.Dense(16, activation='relu')(H1)
    V_s = tf.keras.layers.Dense(1)(H3) #https://stackoverflow.com/questions/62336594/dueling-dqn-with-keras
    advantage = tf.keras.layers.Dense(2)(H3) #https://stackoverflow.com/questions/62336594/dueling-dqn-with-keras
    output_layer = (V_s + (advantage - tf.math.reduce_mean(advantage, axis=1, keepdims=True)))
    model = tf.keras.Model(inputs = input_layer, outputs = output_layer,name = name)
    model.compile(optimizer='adam',
                  loss="mse",
                  metrics=['accuracy'])
    model.summary()
    return model
model = create_model(name = "QNN")
# Target network
model2 = create_model(name = "TagretNetwork")



def replay(buffer, minibatch_size,timestep,epsoide_num):
    if timestep <= 500:
        return model
    else:
        minibatch = np.random.choice(buffer, minibatch_size, replace=False)
        s_l =      np.array(list(map(lambda x: x['s'], minibatch)))
        a_l =      np.array(list(map(lambda x: x['a'], minibatch)))
        r_l =      np.array(list(map(lambda x: x['r'], minibatch)))
        sprime_l = np.array(list(map(lambda x: x['sprime'], minibatch)))
        done_l   = np.array(list(map(lambda x: x['done'], minibatch)))
        current_qs = model.predict(s_l)
        Q_qnn = model.predict(sprime_l)
        Q_tgt = model2.predict(sprime_l)

        if epsoide_num % 10 == 0 and epsoide_num != 0:
            model2.set_weights(model.get_weights())   
        # q-update

        for i,(s,a,r,done,sprimeQnn,sprimeTgt) in enumerate(zip(s_l,a_l,r_l,done_l,Q_qnn,Q_tgt)):
            Q_DDQN = sprimeTgt[np.argmax(sprimeQnn)]
            if not done:  target = r + Q_DDQN
            else:         target = r
            # Update Q value for given state
            current_qs[i][a] = target
            # And append to our training data
        model.fit(s_l,current_qs,batch_size = minibatch_size,epochs=1,verbose=0)
        return model
# Out:
# Model: "QNN"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 4)]          0
# __________________________________________________________________________________________________
# dense (Dense)                   (None, 32)           160         input_1[0][0]
# __________________________________________________________________________________________________
# dense_1 (Dense)                 (None, 16)           528         dense[0][0]
# __________________________________________________________________________________________________
# dense_3 (Dense)                 (None, 2)            34          dense_1[0][0]
# __________________________________________________________________________________________________
# tf.math.reduce_mean (TFOpLambda (None, 1)            0           dense_3[0][0]
# __________________________________________________________________________________________________
# dense_2 (Dense)                 (None, 1)            17          dense_1[0][0]
# __________________________________________________________________________________________________
# tf.math.subtract (TFOpLambda)   (None, 2)            0           dense_3[0][0]
#                                                                  tf.math.reduce_mean[0][0]
# __________________________________________________________________________________________________
# tf.__operators__.add (TFOpLambd (None, 2)            0           dense_2[0][0]
#                                                                  tf.math.subtract[0][0]
# ==================================================================================================
# Total params: 739
# Trainable params: 739
# Non-trainable params: 0
# __________________________________________________________________________________________________
# Model: "TagretNetwork"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_2 (InputLayer)            [(None, 4)]          0
# __________________________________________________________________________________________________
# dense_4 (Dense)                 (None, 32)           160         input_2[0][0]
# __________________________________________________________________________________________________
# dense_5 (Dense)                 (None, 16)           528         dense_4[0][0]
# __________________________________________________________________________________________________
# dense_7 (Dense)                 (None, 2)            34          dense_5[0][0]
# __________________________________________________________________________________________________
# tf.math.reduce_mean_1 (TFOpLamb (None, 1)            0           dense_7[0][0]
# __________________________________________________________________________________________________
# dense_6 (Dense)                 (None, 1)            17          dense_5[0][0]
# __________________________________________________________________________________________________
# tf.math.subtract_1 (TFOpLambda) (None, 2)            0           dense_7[0][0]
#                                                                  tf.math.reduce_mean_1[0][0]
# __________________________________________________________________________________________________
# tf.__operators__.add_1 (TFOpLam (None, 2)            0           dense_6[0][0]
#                                                                  tf.math.subtract_1[0][0]
# ==================================================================================================
# Total params: 739
# Trainable params: 739
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
from random import randrange

# hyper parameter
n_episodes = 2500
epsilon = 0.9
minibatch_size = 32
r_sums = []  # stores rewards of each epsiode 
buffer = [] # replay memory holds s, a, r, s'
win_weight_eps_tstep = []
mem_max_size = 10000
init_seed=123
timestep = 0
eps = 0
np.random.seed(123)


for n in range(n_episodes): 
    env.seed(seed=init_seed+n)
    s = env.reset()
    s = discretizaion(s)
    done=False
    r_sum = 0
    while not done: 
        # Uncomment this to see the agent learning
        # env.render()
        # Feedforward pass for current state to get predicted q-values for all actions 
        qvals_s = model.predict(s.reshape(1,4))
        # Choose action to be epsilon-greedy
        if np.random.random() < epsilon:  
            a = randrange(1)
        else:                             
            a = np.argmax(qvals_s)
        # Take step, store results 
        sprime, r, done, info = env.step(a)
        sprime = discretizaion(sprime)
        r_sum += r 
        # add to memory, respecting memory buffer limit 
        if len(buffer) > mem_max_size:
            buffer.pop(0)
        buffer.append({"s":s,"a":a,"r":r,"sprime":sprime,"done":done})
        # Update state
        s=sprime
        # Train the nnet that approximates q(s,a), using the replay memory
        model=replay(buffer, minibatch_size = minibatch_size, timestep = timestep, epsoide_num = n)
        # Decrease epsilon until we hit a target threshold 
        timestep += 1
        if timestep % 1000 == 0 and timestep != 0:
            print("timestep",timestep)
    if r_sum > 0:
        win_weight_eps_tstep.append((model.get_weights(),n,timestep))    
    epsilon -= 0.001
    if epsilon <= 0.0005:
        eps += 0.001
        epsilon = 0.001
        if eps == 0.001:
            print("In the timestep of ", timestep, ", epsilon is fixed at",epsilon)     
    #print("Total reward:", r_sum)
    r_sums.append(r_sum)
    if n % 100 == 0: 
        print(n,"\n")
        print("r_score", np.round(np.mean(np.array(r_sums)), 3), "±", 2*np.round(np.std(np.array(r_sums)), 3), "vs", "Baseline", "over", n+1, "trials. \n")
        print("rsums_lastest_10",r_sums[-10:],"\n")
# Out:
# 0
#
# r_score 11.0 ± 0.0 vs Baseline over 1 trials.
#
# rsums_lastest_10 [11.0]
#
# timestep 1000
# 100
#
# r_score 10.03 ± 3.152 vs Baseline over 101 trials.
#
# rsums_lastest_10 [10.0, 10.0, 9.0, 9.0, 8.0, 10.0, 11.0, 9.0, 9.0, 10.0]
#
# timestep 2000
# 200
#
# r_score 10.617 ± 6.254 vs Baseline over 201 trials.
#
# rsums_lastest_10 [10.0, 12.0, 11.0, 13.0, 23.0, 30.0, 26.0, 20.0, 13.0, 11.0]
#
# timestep 3000
# 300
#
# r_score 13.017 ± 13.88 vs Baseline over 301 trials.
#
# rsums_lastest_10 [51.0, 14.0, 24.0, 32.0, 12.0, 15.0, 44.0, 13.0, 65.0, 13.0]
#
# timestep 4000
# timestep 5000
# timestep 6000
# 400
#
# r_score 16.224 ± 22.216 vs Baseline over 401 trials.
#
# rsums_lastest_10 [115.0, 18.0, 19.0, 19.0, 11.0, 30.0, 23.0, 23.0, 50.0, 18.0]
#
# timestep 7000
# timestep 8000
# timestep 9000
# 500
#
# r_score 19.259 ± 28.462 vs Baseline over 501 trials.
#
# rsums_lastest_10 [27.0, 16.0, 45.0, 45.0, 28.0, 89.0, 65.0, 31.0, 32.0, 22.0]
#
# timestep 10000
# timestep 11000
# timestep 12000
# timestep 13000
# timestep 14000
# timestep 15000
# 600
#
# r_score 26.434 ± 51.214 vs Baseline over 601 trials.
#
# rsums_lastest_10 [29.0, 37.0, 59.0, 55.0, 92.0, 79.0, 80.0, 77.0, 81.0, 64.0]
#
# timestep 16000
# timestep 17000
# timestep 18000
# timestep 19000
# timestep 20000
# timestep 21000
# timestep 22000
# timestep 23000
# timestep 24000
# timestep 25000
# 700
#
# r_score 35.819 ± 72.176 vs Baseline over 701 trials.
#
# rsums_lastest_10 [94.0, 73.0, 83.0, 16.0, 80.0, 54.0, 66.0, 69.0, 76.0, 92.0]
#
# timestep 26000
# timestep 27000
# timestep 28000
# timestep 29000
# timestep 30000
# timestep 31000
# timestep 32000
# timestep 33000
# timestep 34000
# timestep 35000
# timestep 36000
# timestep 37000
# timestep 38000
# timestep 39000
# 800
#
# r_score 49.233 ± 101.028 vs Baseline over 801 trials.
#
# rsums_lastest_10 [91.0, 148.0, 173.0, 116.0, 200.0, 179.0, 155.0, 144.0, 200.0, 158.0]
#
# timestep 40000
# timestep 41000
# timestep 42000
# timestep 43000
# timestep 44000
# timestep 45000
# timestep 46000
# timestep 47000
# timestep 48000
# timestep 49000
# timestep 50000
# timestep 51000
# timestep 52000
# timestep 53000
# timestep 54000
# timestep 55000
# timestep 56000
# timestep 57000
# In the timestep of  57462 , epsilon is fixed at 0.001
# 900
#
# r_score 63.998 ± 127.718 vs Baseline over 901 trials.
#
# rsums_lastest_10 [200.0, 200.0, 200.0, 184.0, 185.0, 200.0, 200.0, 200.0, 200.0, 200.0]
#
# timestep 58000
# timestep 59000
# timestep 60000
# timestep 61000
# timestep 62000
# timestep 63000
# timestep 64000
# timestep 65000
# timestep 66000
# timestep 67000
# timestep 68000
# timestep 69000
# timestep 70000
# 1000
#
# r_score 70.716 ± 135.862 vs Baseline over 1001 trials.
#
# rsums_lastest_10 [200.0, 200.0, 162.0, 143.0, 200.0, 200.0, 200.0, 155.0, 200.0, 200.0]
#
# timestep 71000
# timestep 72000
# timestep 73000
# timestep 74000
# timestep 75000
# timestep 76000
# timestep 77000
# timestep 78000
# timestep 79000
# timestep 80000
# timestep 81000
# timestep 82000
# timestep 83000
# timestep 84000
# 1100
#
# r_score 77.099 ± 138.38 vs Baseline over 1101 trials.
#
# rsums_lastest_10 [164.0, 139.0, 126.0, 200.0, 174.0, 200.0, 105.0, 200.0, 136.0, 200.0]
#
# timestep 85000
# timestep 86000
# timestep 87000
# timestep 88000
# timestep 89000
# timestep 90000
# timestep 91000
# timestep 92000
# timestep 93000
# timestep 94000
# timestep 95000
# timestep 96000
# timestep 97000
# timestep 98000
# timestep 99000
# timestep 100000
# timestep 101000
# 1200
#
# r_score 84.714 ± 143.102 vs Baseline over 1201 trials.
#
# rsums_lastest_10 [167.0, 174.0, 192.0, 189.0, 200.0, 200.0, 200.0, 200.0, 200.0, 200.0]
#
# timestep 102000
# timestep 103000
# timestep 104000
# timestep 105000
# timestep 106000
# timestep 107000
# timestep 108000
# timestep 109000
# timestep 110000
# timestep 111000
# timestep 112000
# timestep 113000
# timestep 114000
# timestep 115000
# timestep 116000
# timestep 117000
# timestep 118000
# 1300
#
# r_score 90.869 ± 146.182 vs Baseline over 1301 trials.
#
# rsums_lastest_10 [140.0, 93.0, 129.0, 133.0, 115.0, 145.0, 143.0, 153.0, 156.0, 157.0]
#
# timestep 119000
# timestep 120000
# timestep 121000
# timestep 122000
# timestep 123000
# timestep 124000
# timestep 125000
# timestep 126000
# timestep 127000
# timestep 128000
# timestep 129000
# timestep 130000
# timestep 131000
# timestep 132000
# timestep 133000
# timestep 134000
# timestep 135000
# timestep 136000
# timestep 137000
# 1400
#
# r_score 97.954 ± 150.118 vs Baseline over 1401 trials.
#
# rsums_lastest_10 [200.0, 200.0, 200.0, 200.0, 200.0, 200.0, 200.0, 200.0, 192.0, 200.0]
#
# timestep 138000
# timestep 139000
# timestep 140000
# timestep 141000
# timestep 142000
# timestep 143000
# timestep 144000
# timestep 145000
# timestep 146000
# timestep 147000
# timestep 148000
# timestep 149000
# timestep 150000
# timestep 151000
# timestep 152000
# timestep 153000
# timestep 154000
# timestep 155000
# timestep 156000
# 1500
#
# r_score 104.359 ± 152.866 vs Baseline over 1501 trials.
#
# rsums_lastest_10 [200.0, 200.0, 200.0, 198.0, 168.0, 200.0, 200.0, 200.0, 200.0, 200.0]
#
# timestep 157000
# timestep 158000
# timestep 159000
# timestep 160000
# timestep 161000
# timestep 162000
# timestep 163000
# timestep 164000
# timestep 165000
# timestep 166000
# timestep 167000
# timestep 168000
# timestep 169000
# timestep 170000
# timestep 171000
# timestep 172000
# timestep 173000
# timestep 174000
# timestep 175000
# timestep 176000
# 1600
#
# r_score 109.978 ± 154.388 vs Baseline over 1601 trials.
#
# rsums_lastest_10 [200.0, 200.0, 200.0, 200.0, 192.0, 200.0, 200.0, 200.0, 200.0, 200.0]
#
# timestep 177000
# timestep 178000
# timestep 179000
# timestep 180000
# timestep 181000
# timestep 182000
# timestep 183000
# timestep 184000
# timestep 185000
# timestep 186000
# timestep 187000
# timestep 188000
# timestep 189000
# timestep 190000
# timestep 191000
# timestep 192000
# timestep 193000
# 1700
#
# r_score 113.47 ± 153.444 vs Baseline over 1701 trials.
#
# rsums_lastest_10 [11.0, 12.0, 53.0, 56.0, 124.0, 119.0, 139.0, 113.0, 108.0, 197.0]
#
# timestep 194000
# timestep 195000
# timestep 196000
# timestep 197000
# timestep 198000
# timestep 199000
# timestep 200000
# timestep 201000
# timestep 202000
# timestep 203000
# timestep 204000
# timestep 205000
# timestep 206000
# 1800
#
# r_score 114.525 ± 150.814 vs Baseline over 1801 trials.
#
# rsums_lastest_10 [129.0, 199.0, 200.0, 146.0, 154.0, 150.0, 200.0, 200.0, 194.0, 200.0]
#
# timestep 207000
# timestep 208000
# timestep 209000
# timestep 210000
# timestep 211000
# timestep 212000
# timestep 213000
# timestep 214000
# timestep 215000
# timestep 216000
# timestep 217000
# timestep 218000
# timestep 219000
# timestep 220000
# timestep 221000
# timestep 222000
# timestep 223000
# 1900
#
# r_score 117.338 ± 150.654 vs Baseline over 1901 trials.
#
# rsums_lastest_10 [133.0, 152.0, 151.0, 155.0, 183.0, 176.0, 144.0, 155.0, 171.0, 83.0]
#
# timestep 224000
# timestep 225000
# timestep 226000
# timestep 227000
# timestep 228000
# timestep 229000
# timestep 230000
# timestep 231000
# timestep 232000
# timestep 233000
# timestep 234000
# timestep 235000
# 2000
#
# r_score 117.767 ± 147.722 vs Baseline over 2001 trials.
#
# rsums_lastest_10 [168.0, 200.0, 200.0, 168.0, 200.0, 200.0, 134.0, 163.0, 131.0, 103.0]
#
# timestep 236000
# timestep 237000
# timestep 238000
# timestep 239000
# timestep 240000
# timestep 241000
# timestep 242000
# timestep 243000
# timestep 244000
# timestep 245000
# timestep 246000
# timestep 247000
# timestep 248000
# timestep 249000
# timestep 250000
# timestep 251000
# 2100
#
# r_score 119.649 ± 146.016 vs Baseline over 2101 trials.
#
# rsums_lastest_10 [188.0, 166.0, 149.0, 140.0, 154.0, 155.0, 173.0, 143.0, 132.0, 145.0]
#
# timestep 252000
# timestep 253000
# timestep 254000
# timestep 255000
# timestep 256000
# timestep 257000
# timestep 258000
# timestep 259000
# timestep 260000
# timestep 261000
# timestep 262000
# timestep 263000
# timestep 264000
# timestep 265000
# timestep 266000
# timestep 267000
# timestep 268000
# 2200
#
# r_score 122.082 ± 144.992 vs Baseline over 2201 trials.
#
# rsums_lastest_10 [73.0, 132.0, 112.0, 122.0, 121.0, 113.0, 111.0, 114.0, 121.0, 83.0]
#
# timestep 269000
# timestep 270000
# timestep 271000
# timestep 272000
# timestep 273000
# timestep 274000
# timestep 275000
# timestep 276000
# timestep 277000
# timestep 278000
# timestep 279000
# timestep 280000
# timestep 281000
# timestep 282000
# timestep 283000
# timestep 284000
# 2300
#
# r_score 123.678 ± 143.184 vs Baseline over 2301 trials.
#
# rsums_lastest_10 [166.0, 200.0, 200.0, 154.0, 162.0, 158.0, 200.0, 143.0, 142.0, 129.0]
#
# timestep 285000
# timestep 286000
# timestep 287000
# timestep 288000
# timestep 289000
# timestep 290000
# timestep 291000
# timestep 292000
# timestep 293000
# timestep 294000
# timestep 295000
# timestep 296000
# timestep 297000
# timestep 298000
# timestep 299000
# timestep 300000
# 2400
#
# r_score 125.325 ± 143.302 vs Baseline over 2401 trials.
#
# rsums_lastest_10 [139.0, 150.0, 153.0, 128.0, 128.0, 149.0, 156.0, 130.0, 130.0, 120.0]
#
# timestep 301000
# timestep 302000
# timestep 303000
# timestep 304000
# timestep 305000
# timestep 306000
# timestep 307000
# timestep 308000
# timestep 309000

# %%
# Plot the performance of the agent 
plt.plot(r_sums)
plt.xlabel("Episode Number")
plt.ylabel("Reward")
# Out:
# Text(0, 0.5, 'Reward')

# %%
import pickle
# Store data (serialize)
with open('cartpole_DuelingDDQN_final_discre.pickle', 'wb') as handle:
    pickle.dump(r_sums +[timestep,], handle)

# %%
with open('cartpole_DuelingDDQN_final_discre.pickle', 'rb') as handle:
    b = pickle.load(handle)

# %%
print(len(b))
b[-1]
# Out:
# 2501
# 309241

# %% [markdown]
# # Dueling DDQN

# %% [markdown]
# I lernt from the following websites to finish the implementations.
# Reference:
# 1. Hung-yi Lee. DRL Lecture 3: Q-learning (Basic Idea)
# https://youtu.be/o_g9JUMw1Oc
# 2. Hung-yi Lee. DRL Lecture 4: Q-learning (Advanced Tips)
# https://www.youtube.com/watch?v=2-zGCx4iv_k&t=980s
# 3. Tensorflow
# https://www.tensorflow.org/api_docs/python/tf/keras/Model
# 4. Tom. Let's build a DQN: simple implementation
# https://tomroth.com.au/dqn-simple/

# %%
import gym
import numpy as np
import matplotlib.pyplot as plt 
# %matplotlib inline
import tensorflow as tf
from random import sample

# Setting up the environment 
env = gym.make("CartPole-v0")

# %%
def create_model(name):
    input_layer = tf.keras.Input(shape = (4,))
    H1 = tf.keras.layers.Dense(32, activation='relu')(input_layer)
    H3 = tf.keras.layers.Dense(16, activation='relu')(H1)
    V_s = tf.keras.layers.Dense(1)(H3) #https://stackoverflow.com/questions/62336594/dueling-dqn-with-keras
    advantage = tf.keras.layers.Dense(2)(H3) #https://stackoverflow.com/questions/62336594/dueling-dqn-with-keras
    output_layer = (V_s + (advantage - tf.math.reduce_mean(advantage, axis=1, keepdims=True)))
    model = tf.keras.Model(inputs = input_layer, outputs = output_layer,name = name)
    model.compile(optimizer='adam',
                  loss="mse",
                  metrics=['accuracy'])
    model.summary()
    return model
model = create_model(name = "QNN")
# Target network
model2 = create_model(name = "TagretNetwork")



def replay(buffer, minibatch_size,timestep,epsoide_num):
    if timestep <= 500:
        return model
    else:
        minibatch = np.random.choice(buffer, minibatch_size, replace=False)
        s_l =      np.array(list(map(lambda x: x['s'], minibatch)))
        a_l =      np.array(list(map(lambda x: x['a'], minibatch)))
        r_l =      np.array(list(map(lambda x: x['r'], minibatch)))
        sprime_l = np.array(list(map(lambda x: x['sprime'], minibatch)))
        done_l   = np.array(list(map(lambda x: x['done'], minibatch)))
        current_qs = model.predict(s_l)
        Q_qnn = model.predict(sprime_l)
        Q_tgt = model2.predict(sprime_l)

        if epsoide_num % 10 == 0 and epsoide_num != 0:
            model2.set_weights(model.get_weights())   
        # q-update

        for i,(s,a,r,done,sprimeQnn,sprimeTgt) in enumerate(zip(s_l,a_l,r_l,done_l,Q_qnn,Q_tgt)):
            Q_DDQN = sprimeTgt[np.argmax(sprimeQnn)]
            if not done:  target = r + Q_DDQN
            else:         target = r
            # Update Q value for given state
            current_qs[i][a] = target
            # And append to our training data
        model.fit(s_l,current_qs,batch_size = minibatch_size,epochs=1,verbose=0)
        return model
# Out:
# Model: "QNN"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 4)]          0
# __________________________________________________________________________________________________
# dense (Dense)                   (None, 32)           160         input_1[0][0]
# __________________________________________________________________________________________________
# dense_1 (Dense)                 (None, 16)           528         dense[0][0]
# __________________________________________________________________________________________________
# dense_3 (Dense)                 (None, 2)            34          dense_1[0][0]
# __________________________________________________________________________________________________
# tf.math.reduce_mean (TFOpLambda (None, 1)            0           dense_3[0][0]
# __________________________________________________________________________________________________
# dense_2 (Dense)                 (None, 1)            17          dense_1[0][0]
# __________________________________________________________________________________________________
# tf.math.subtract (TFOpLambda)   (None, 2)            0           dense_3[0][0]
#                                                                  tf.math.reduce_mean[0][0]
# __________________________________________________________________________________________________
# tf.__operators__.add (TFOpLambd (None, 2)            0           dense_2[0][0]
#                                                                  tf.math.subtract[0][0]
# ==================================================================================================
# Total params: 739
# Trainable params: 739
# Non-trainable params: 0
# __________________________________________________________________________________________________
# Model: "TagretNetwork"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_2 (InputLayer)            [(None, 4)]          0
# __________________________________________________________________________________________________
# dense_4 (Dense)                 (None, 32)           160         input_2[0][0]
# __________________________________________________________________________________________________
# dense_5 (Dense)                 (None, 16)           528         dense_4[0][0]
# __________________________________________________________________________________________________
# dense_7 (Dense)                 (None, 2)            34          dense_5[0][0]
# __________________________________________________________________________________________________
# tf.math.reduce_mean_1 (TFOpLamb (None, 1)            0           dense_7[0][0]
# __________________________________________________________________________________________________
# dense_6 (Dense)                 (None, 1)            17          dense_5[0][0]
# __________________________________________________________________________________________________
# tf.math.subtract_1 (TFOpLambda) (None, 2)            0           dense_7[0][0]
#                                                                  tf.math.reduce_mean_1[0][0]
# __________________________________________________________________________________________________
# tf.__operators__.add_1 (TFOpLam (None, 2)            0           dense_6[0][0]
#                                                                  tf.math.subtract_1[0][0]
# ==================================================================================================
# Total params: 739
# Trainable params: 739
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
from random import randrange

# hyper parameter
n_episodes = 2500
epsilon = 0.9
minibatch_size = 32
r_sums = []  # stores rewards of each epsiode 
buffer = [] # replay memory holds s, a, r, s'
win_weight_eps_tstep = []
mem_max_size = 10000
init_seed=123
timestep = 0
eps = 0
np.random.seed(123)


for n in range(n_episodes): 
    env.seed(seed=init_seed+n)
    s = env.reset()
    done=False
    r_sum = 0
    while not done: 
        # Uncomment this to see the agent learning
        # env.render()
        # Feedforward pass for current state to get predicted q-values for all actions 
        qvals_s = model.predict(s.reshape(1,4))
        # Choose action to be epsilon-greedy
        if np.random.random() < epsilon:  
            a = randrange(1)
        else:                             
            a = np.argmax(qvals_s)
        # Take step, store results 
        sprime, r, done, info = env.step(a)
        r_sum += r 
        # add to memory, respecting memory buffer limit 
        if len(buffer) > mem_max_size:
            buffer.pop(0)
        buffer.append({"s":s,"a":a,"r":r,"sprime":sprime,"done":done})
        # Update state
        s=sprime
        # Train the nnet that approximates q(s,a), using the replay memory
        model=replay(buffer, minibatch_size = minibatch_size, timestep = timestep, epsoide_num = n)
        # Decrease epsilon until we hit a target threshold 
        timestep += 1
        if timestep % 1000 == 0 and timestep != 0:
            print("timestep",timestep)
    if r_sum > 0:
        win_weight_eps_tstep.append((model.get_weights(),n,timestep))    
    epsilon -= 0.001
    if epsilon <= 0.0005:
        eps += 0.001
        epsilon = 0.001
        if eps == 0.001:
            print("In the timestep of ", timestep, ", epsilon is fixed at",epsilon)     
    #print("Total reward:", r_sum)
    r_sums.append(r_sum)
    if n % 100 == 0: 
        print(n,"\n")
        print("r_score", np.round(np.mean(np.array(r_sums)), 3), "±", 2*np.round(np.std(np.array(r_sums)), 3), "vs", "Baseline", "over", n+1, "trials. \n")
        print("rsums_lastest100",r_sums[-100:],"\n")
# Out:
# 0
#
# r_score 11.0 ± 0.0 vs Baseline over 1 trials.
#
# rsums_lastest100 [11.0]
#
# timestep 1000
# 100
#
# r_score 10.04 ± 3.056 vs Baseline over 101 trials.
#
# rsums_lastest100 [9.0, 11.0, 9.0, 9.0, 9.0, 9.0, 10.0, 10.0, 10.0, 10.0, 10.0, 15.0, 11.0, 9.0, 11.0, 9.0, 10.0, 9.0, 9.0, 9.0, 9.0, 13.0, 12.0, 9.0, 10.0, 11.0, 8.0, 10.0, 17.0, 11.0, 10.0, 12.0, 10.0, 11.0, 8.0, 9.0, 12.0, 11.0, 13.0, 12.0, 10.0, 10.0, 10.0, 13.0, 10.0, 8.0, 17.0, 9.0, 9.0, 12.0, 9.0, 10.0, 9.0, 10.0, 9.0, 10.0, 9.0, 10.0, 9.0, 10.0, 9.0, 10.0, 10.0, 10.0, 9.0, 10.0, 9.0, 9.0, 10.0, 10.0, 8.0, 10.0, 10.0, 10.0, 9.0, 9.0, 10.0, 9.0, 10.0, 9.0, 9.0, 9.0, 10.0, 10.0, 10.0, 9.0, 11.0, 10.0, 10.0, 9.0, 10.0, 10.0, 9.0, 9.0, 8.0, 11.0, 11.0, 9.0, 10.0, 10.0]
0, 200.0, 200.0, 200.0, 200.0, 200.0, 200.0, 200.0, 200.0, 200.0, 200.0, 200.0, 200.0, 190.0, 168.0, 173.0, 141.0, 137.0, 139.0, 121.0, 120.0, 134.0, 147.0, 144.0, 128.0, 133.0, 153.0, 157.0, 200.0, 200.0, 154.0, 171.0, 125.0, 200.0, 191.0, 186.0, 200.0, 172.0, 200.0, 198.0, 151.0, 136.0, 177.0, 200.0, 200.0, 196.0, 134.0, 161.0, 133.0, 141.0, 184.0, 161.0, 154.0, 131.0, 106.0, 166.0, 98.0, 102.0, 93.0, 148.0, 82.0, 114.0]
#
# timestep 97000
# timestep 98000
# timestep 99000
# timestep 100000
# timestep 101000
# timestep 102000
# timestep 103000
# timestep 104000
# timestep 105000
# timestep 106000
# timestep 107000
# timestep 108000
# timestep 109000
# 1300
#
# r_score 83.889 ± 136.932 vs Baseline over 1301 trials.
#
# rsums_lastest100 [200.0, 188.0, 106.0, 200.0, 144.0, 200.0, 140.0, 100.0, 107.0, 108.0, 101.0, 160.0, 138.0, 170.0, 131.0, 200.0, 150.0, 141.0, 158.0, 124.0, 155.0, 109.0, 101.0, 109.0, 127.0, 104.0, 100.0, 100.0, 200.0, 88.0, 78.0, 97.0, 111.0, 96.0, 87.0, 121.0, 94.0, 108.0, 108.0, 87.0, 84.0, 99.0, 65.0, 77.0, 73.0, 75.0, 64.0, 66.0, 89.0, 74.0, 52.0, 61.0, 54.0, 59.0, 54.0, 62.0, 54.0, 70.0, 62.0, 57.0, 44.0, 54.0, 59.0, 145.0, 151.0, 152.0, 105.0, 94.0, 177.0, 94.0, 42.0, 85.0, 63.0, 83.0, 67.0, 179.0, 167.0, 193.0, 175.0, 97.0, 200.0, 200.0, 200.0, 200.0, 200.0, 200.0, 200.0, 200.0, 200.0, 200.0, 200.0, 200.0, 197.0, 184.0, 169.0, 153.0, 150.0, 160.0, 146.0, 119.0]
#
# timestep 110000
# timestep 111000
# timestep 112000
# timestep 113000
# timestep 114000
# 1400
#
# r_score 81.675 ± 138.642 vs Baseline over 1401 trials.
#
# rsums_lastest100 [12.0, 85.0, 87.0, 103.0, 130.0, 140.0, 152.0, 176.0, 182.0, 171.0, 10.0, 11.0, 8.0, 10.0, 9.0, 9.0, 11.0, 11.0, 10.0, 9.0, 9.0, 10.0, 9.0, 10.0, 10.0, 11.0, 12.0, 10.0, 10.0, 11.0, 9.0, 12.0, 12.0, 12.0, 11.0, 11.0, 11.0, 10.0, 12.0, 11.0, 10.0, 12.0, 10.0, 13.0, 14.0, 200.0, 200.0, 200.0, 200.0, 200.0, 200.0, 200.0, 200.0, 200.0, 200.0, 200.0, 200.0, 200.0, 200.0, 200.0, 15.0, 12.0, 11.0, 12.0, 10.0, 10.0, 11.0, 9.0, 10.0, 9.0, 9.0, 9.0, 10.0, 9.0, 9.0, 10.0, 10.0, 11.0, 10.0, 11.0, 10.0, 11.0, 11.0, 11.0, 11.0, 10.0, 10.0, 11.0, 12.0, 12.0, 9.0, 12.0, 13.0, 10.0, 12.0, 11.0, 12.0, 12.0, 129.0, 143.0]
#
# timestep 115000
# timestep 116000
# timestep 117000
# timestep 118000
# timestep 119000
# timestep 120000
# timestep 121000
# timestep 122000
# timestep 123000
# timestep 124000
# timestep 125000
# timestep 126000
# timestep 127000
# timestep 128000
# timestep 129000
# timestep 130000
# timestep 131000
# timestep 132000
# timestep 133000
# timestep 134000
# 1500
#
# r_score 89.364 ± 145.844 vs Baseline over 1501 trials.
#
# rsums_lastest100 [200.0, 200.0, 200.0, 200.0, 200.0, 200.0, 200.0, 200.0, 200.0, 200.0, 200.0, 200.0, 200.0, 200.0, 200.0, 200.0, 200.0, 200.0, 200.0, 200.0, 200.0, 200.0, 200.0, 200.0, 200.0, 200.0, 200.0, 200.0, 200.0, 200.0, 200.0, 200.0, 200.0, 198.0, 200.0, 200.0, 200.0, 192.0, 190.0, 200.0, 183.0, 171.0, 186.0, 171.0, 199.0, 197.0, 177.0, 183.0, 179.0, 200.0, 179.0, 200.0, 200.0, 200.0, 200.0, 200.0, 200.0, 200.0, 200.0, 200.0, 200.0, 200.0, 200.0, 200.0, 200.0, 200.0, 200.0, 200.0, 200.0, 200.0, 200.0, 200.0, 200.0, 200.0, 200.0, 200.0, 200.0, 200.0, 200.0, 200.0, 200.0, 200.0, 200.0, 200.0, 189.0, 200.0, 200.0, 160.0, 193.0, 173.0, 200.0, 200.0, 200.0, 200.0, 200.0, 200.0, 200.0, 197.0, 193.0, 200.0]
#
# timestep 135000
# timestep 136000
# timestep 137000
# timestep 138000
# timestep 139000
# timestep 140000
# timestep 141000
# timestep 142000
# timestep 143000
# timestep 144000
# timestep 145000
# timestep 146000
# timestep 147000
# timestep 148000
# timestep 149000
# timestep 150000
# timestep 151000
# timestep 152000
# timestep 153000
# timestep 154000
# 1600
#
# r_score 96.275 ± 151.026 vs Baseline over 1601 trials.
#
# rsums_lastest100 [200.0, 200.0, 200.0, 200.0, 200.0, 200.0, 200.0, 200.0, 200.0, 200.0, 200.0, 200.0, 200.0, 200.0, 200.0, 200.0, 200.0, 200.0, 200.0, 200.0, 200.0, 200.0, 200.0, 200.0, 200.0, 200.0, 200.0, 200.0, 200.0, 200.0, 200.0, 200.0, 200.0, 200.0, 200.0, 200.0, 200.0, 200.0, 200.0, 200.0, 200.0, 200.0, 200.0, 200.0, 200.0, 200.0, 200.0, 200.0, 200.0, 200.0, 200.0, 200.0, 200.0, 200.0, 200.0, 200.0, 200.0, 200.0, 200.0, 200.0, 200.0, 200.0, 200.0, 200.0, 200.0, 200.0, 200.0, 200.0, 200.0, 200.0, 200.0, 200.0, 200.0, 200.0, 200.0, 200.0, 200.0, 200.0, 200.0, 200.0, 200.0, 200.0, 200.0, 200.0, 200.0, 200.0, 200.0, 200.0, 200.0, 200.0, 200.0, 200.0, 200.0, 200.0, 200.0, 200.0, 200.0, 200.0, 200.0, 200.0]
#
# timestep 155000
# timestep 156000
# timestep 157000
# timestep 158000
# timestep 159000
# timestep 160000
# timestep 161000
# timestep 162000
# timestep 163000
# timestep 164000
# timestep 165000
# timestep 166000
# timestep 167000
# timestep 168000
# timestep 169000
# timestep 170000
# 1700
#
# r_score 100.27 ± 153.856 vs Baseline over 1701 trials.
#
# rsums_lastest100 [200.0, 200.0, 200.0, 200.0, 200.0, 200.0, 200.0, 200.0, 200.0, 200.0, 200.0, 200.0, 200.0, 200.0, 200.0, 200.0, 200.0, 200.0, 200.0, 200.0, 200.0, 200.0, 200.0, 200.0, 200.0, 200.0, 200.0, 200.0, 200.0, 200.0, 200.0, 200.0, 200.0, 200.0, 200.0, 200.0, 200.0, 200.0, 200.0, 200.0, 200.0, 200.0, 200.0, 200.0, 200.0, 200.0, 200.0, 200.0, 200.0, 200.0, 200.0, 200.0, 200.0, 200.0, 200.0, 200.0, 200.0, 200.0, 200.0, 200.0, 200.0, 200.0, 200.0, 200.0, 200.0, 200.0, 200.0, 200.0, 200.0, 200.0, 200.0, 200.0, 200.0, 200.0, 200.0, 200.0, 200.0, 200.0, 200.0, 163.0, 18.0, 23.0, 14.0, 10.0, 18.0, 10.0, 9.0, 18.0, 10.0, 19.0, 17.0, 22.0, 37.0, 32.0, 31.0, 31.0, 23.0, 34.0, 32.0, 52.0]
#
# timestep 171000
# timestep 172000
# timestep 173000
# timestep 174000
# timestep 175000
# timestep 176000
# timestep 177000
# timestep 178000
# timestep 179000
# timestep 180000
# timestep 181000
# timestep 182000
# timestep 183000
# timestep 184000
# timestep 185000
# timestep 186000
# timestep 187000
# timestep 188000
# timestep 189000
# timestep 190000
# 1800
#
# r_score 105.807 ± 156.344 vs Baseline over 1801 trials.
#
# rsums_lastest100 [200.0, 200.0, 200.0, 200.0, 200.0, 200.0, 200.0, 200.0, 200.0, 200.0, 200.0, 200.0, 200.0, 200.0, 200.0, 200.0, 200.0, 200.0, 200.0, 200.0, 200.0, 200.0, 200.0, 200.0, 200.0, 200.0, 200.0, 200.0, 200.0, 200.0, 200.0, 200.0, 200.0, 200.0, 200.0, 200.0, 200.0, 200.0, 200.0, 200.0, 200.0, 200.0, 200.0, 200.0, 200.0, 200.0, 200.0, 200.0, 200.0, 200.0, 200.0, 200.0, 200.0, 200.0, 200.0, 200.0, 200.0, 200.0, 200.0, 200.0, 200.0, 200.0, 200.0, 200.0, 200.0, 200.0, 200.0, 200.0, 200.0, 200.0, 200.0, 200.0, 200.0, 200.0, 200.0, 200.0, 200.0, 200.0, 200.0, 200.0, 200.0, 200.0, 200.0, 200.0, 200.0, 200.0, 200.0, 200.0, 200.0, 200.0, 200.0, 200.0, 200.0, 200.0, 200.0, 200.0, 200.0, 200.0, 200.0, 200.0]
#
# timestep 191000
# timestep 192000
# timestep 193000
# timestep 194000
# timestep 195000
# timestep 196000
# timestep 197000
# timestep 198000
# timestep 199000
# timestep 200000
# timestep 201000
# timestep 202000
# timestep 203000
# timestep 204000
# timestep 205000
# timestep 206000
# timestep 207000
# timestep 208000
# timestep 209000
# timestep 210000
# 1900
#
# r_score 110.762 ± 157.88 vs Baseline over 1901 trials.
#
# rsums_lastest100 [200.0, 200.0, 200.0, 200.0, 200.0, 200.0, 200.0, 200.0, 200.0, 200.0, 200.0, 200.0, 200.0, 200.0, 200.0, 200.0, 200.0, 200.0, 200.0, 200.0, 200.0, 200.0, 200.0, 200.0, 200.0, 200.0, 200.0, 200.0, 200.0, 200.0, 200.0, 200.0, 200.0, 200.0, 200.0, 200.0, 200.0, 200.0, 200.0, 200.0, 200.0, 200.0, 200.0, 200.0, 200.0, 200.0, 200.0, 200.0, 200.0, 200.0, 200.0, 200.0, 200.0, 200.0, 200.0, 200.0, 200.0, 200.0, 200.0, 200.0, 200.0, 200.0, 200.0, 200.0, 200.0, 200.0, 200.0, 200.0, 200.0, 200.0, 200.0, 200.0, 200.0, 200.0, 200.0, 200.0, 200.0, 200.0, 200.0, 200.0, 200.0, 200.0, 200.0, 200.0, 200.0, 200.0, 200.0, 200.0, 200.0, 200.0, 200.0, 200.0, 200.0, 200.0, 200.0, 200.0, 200.0, 200.0, 200.0, 200.0]
#
# timestep 211000
# timestep 212000
# timestep 213000
# timestep 214000
# timestep 215000
# timestep 216000
# timestep 217000
# timestep 218000
# timestep 219000
# timestep 220000
# timestep 221000
# timestep 222000
# timestep 223000
# timestep 224000
# timestep 225000
# timestep 226000
# timestep 227000
# timestep 228000
# 2000
#
# r_score 114.382 ± 157.4 vs Baseline over 2001 trials.
#
# rsums_lastest100 [200.0, 200.0, 200.0, 200.0, 200.0, 200.0, 200.0, 200.0, 200.0, 189.0, 189.0, 198.0, 200.0, 190.0, 200.0, 200.0, 200.0, 190.0, 200.0, 182.0, 198.0, 200.0, 200.0, 200.0, 200.0, 192.0, 200.0, 189.0, 192.0, 174.0, 191.0, 182.0, 192.0, 176.0, 186.0, 180.0, 180.0, 181.0, 197.0, 163.0, 144.0, 178.0, 170.0, 156.0, 180.0, 177.0, 157.0, 170.0, 170.0, 141.0, 143.0, 159.0, 158.0, 154.0, 153.0, 139.0, 146.0, 145.0, 145.0, 124.0, 123.0, 157.0, 158.0, 166.0, 164.0, 174.0, 160.0, 173.0, 165.0, 157.0, 200.0, 200.0, 200.0, 200.0, 200.0, 200.0, 200.0, 200.0, 200.0, 200.0, 200.0, 200.0, 200.0, 200.0, 200.0, 200.0, 200.0, 200.0, 200.0, 200.0, 103.0, 200.0, 200.0, 200.0, 200.0, 200.0, 200.0, 200.0, 200.0, 200.0]
#
# timestep 229000
# timestep 230000
# timestep 231000
# timestep 232000
# timestep 233000
# timestep 234000
# timestep 235000
# timestep 236000
# timestep 237000
# timestep 238000
# timestep 239000
# 2100
#
# r_score 113.826 ± 156.48 vs Baseline over 2101 trials.
#
# rsums_lastest100 [93.0, 115.0, 125.0, 140.0, 140.0, 156.0, 168.0, 161.0, 178.0, 186.0, 128.0, 122.0, 123.0, 119.0, 128.0, 125.0, 124.0, 116.0, 122.0, 117.0, 106.0, 98.0, 105.0, 109.0, 104.0, 98.0, 95.0, 103.0, 102.0, 103.0, 18.0, 15.0, 13.0, 11.0, 16.0, 12.0, 16.0, 16.0, 16.0, 13.0, 14.0, 14.0, 16.0, 16.0, 18.0, 20.0, 20.0, 19.0, 17.0, 16.0, 21.0, 17.0, 15.0, 13.0, 20.0, 20.0, 22.0, 17.0, 21.0, 17.0, 17.0, 25.0, 98.0, 104.0, 101.0, 106.0, 114.0, 107.0, 110.0, 113.0, 115.0, 120.0, 120.0, 117.0, 117.0, 118.0, 119.0, 125.0, 116.0, 127.0, 173.0, 200.0, 200.0, 200.0, 200.0, 200.0, 200.0, 200.0, 200.0, 200.0, 200.0, 200.0, 200.0, 200.0, 200.0, 200.0, 200.0, 200.0, 200.0, 200.0]
#
# timestep 240000
# timestep 241000
# timestep 242000
# timestep 243000
# timestep 244000
# timestep 245000
# timestep 246000
# timestep 247000
# timestep 248000
# timestep 249000
# timestep 250000
# timestep 251000
# timestep 252000
# timestep 253000
# timestep 254000
# timestep 255000
# timestep 256000
# timestep 257000
# timestep 258000
# timestep 259000
# 2200
#
# r_score 117.741 ± 157.04 vs Baseline over 2201 trials.
#
# rsums_lastest100 [200.0, 200.0, 200.0, 200.0, 200.0, 200.0, 200.0, 200.0, 200.0, 200.0, 200.0, 200.0, 200.0, 200.0, 200.0, 200.0, 200.0, 200.0, 200.0, 200.0, 200.0, 200.0, 200.0, 200.0, 200.0, 200.0, 200.0, 200.0, 200.0, 200.0, 200.0, 200.0, 200.0, 200.0, 200.0, 200.0, 200.0, 200.0, 200.0, 200.0, 200.0, 200.0, 200.0, 200.0, 200.0, 200.0, 200.0, 200.0, 200.0, 200.0, 200.0, 200.0, 200.0, 200.0, 200.0, 200.0, 200.0, 200.0, 200.0, 200.0, 200.0, 200.0, 200.0, 200.0, 200.0, 200.0, 200.0, 200.0, 200.0, 200.0, 200.0, 200.0, 200.0, 200.0, 200.0, 200.0, 200.0, 200.0, 200.0, 200.0, 200.0, 200.0, 200.0, 200.0, 200.0, 200.0, 200.0, 200.0, 200.0, 200.0, 200.0, 200.0, 200.0, 200.0, 200.0, 200.0, 200.0, 200.0, 200.0, 200.0]
#
# timestep 260000
# timestep 261000
# timestep 262000
# timestep 263000
# timestep 264000
# timestep 265000
# timestep 266000
# timestep 267000
# timestep 268000
# timestep 269000
# timestep 270000
# timestep 271000
# timestep 272000
# timestep 273000
# timestep 274000
# timestep 275000
# timestep 276000
# timestep 277000
# timestep 278000
# timestep 279000
# 2300
#
# r_score 121.316 ± 157.21 vs Baseline over 2301 trials.
#
# rsums_lastest100 [200.0, 200.0, 200.0, 200.0, 200.0, 200.0, 200.0, 200.0, 200.0, 200.0, 200.0, 200.0, 200.0, 200.0, 200.0, 200.0, 200.0, 200.0, 200.0, 200.0, 200.0, 200.0, 200.0, 200.0, 200.0, 200.0, 200.0, 200.0, 200.0, 200.0, 200.0, 200.0, 200.0, 200.0, 200.0, 200.0, 200.0, 200.0, 200.0, 200.0, 200.0, 200.0, 200.0, 200.0, 200.0, 200.0, 200.0, 200.0, 200.0, 200.0, 200.0, 200.0, 200.0, 200.0, 200.0, 200.0, 200.0, 200.0, 200.0, 200.0, 200.0, 200.0, 200.0, 200.0, 200.0, 200.0, 200.0, 200.0, 200.0, 200.0, 200.0, 200.0, 200.0, 200.0, 200.0, 200.0, 200.0, 200.0, 200.0, 200.0, 200.0, 200.0, 200.0, 200.0, 200.0, 200.0, 200.0, 200.0, 200.0, 200.0, 200.0, 200.0, 200.0, 200.0, 200.0, 200.0, 200.0, 200.0, 200.0, 200.0]
#
# timestep 280000
# timestep 281000
# timestep 282000
# timestep 283000
# timestep 284000
# timestep 285000
# timestep 286000
# timestep 287000
# timestep 288000
# timestep 289000
# timestep 290000
# timestep 291000
# timestep 292000
# timestep 293000
# timestep 294000
# timestep 295000
# timestep 296000
# timestep 297000
# timestep 298000
# timestep 299000
# 2400
#
# r_score 124.594 ± 157.08 vs Baseline over 2401 trials.
#
# rsums_lastest100 [200.0, 200.0, 200.0, 200.0, 200.0, 200.0, 200.0, 200.0, 200.0, 200.0, 200.0, 200.0, 200.0, 200.0, 200.0, 200.0, 200.0, 200.0, 200.0, 200.0, 200.0, 200.0, 200.0, 200.0, 200.0, 200.0, 200.0, 200.0, 200.0, 200.0, 200.0, 200.0, 200.0, 200.0, 200.0, 200.0, 200.0, 200.0, 200.0, 200.0, 200.0, 200.0, 200.0, 200.0, 200.0, 200.0, 200.0, 200.0, 200.0, 200.0, 200.0, 200.0, 200.0, 200.0, 200.0, 200.0, 200.0, 200.0, 200.0, 200.0, 200.0, 200.0, 200.0, 200.0, 200.0, 200.0, 200.0, 200.0, 200.0, 200.0, 200.0, 200.0, 200.0, 200.0, 200.0, 200.0, 200.0, 200.0, 200.0, 200.0, 200.0, 200.0, 200.0, 200.0, 200.0, 200.0, 200.0, 200.0, 200.0, 200.0, 200.0, 200.0, 200.0, 200.0, 200.0, 200.0, 200.0, 200.0, 200.0, 200.0]
#
# timestep 300000
# timestep 301000
# timestep 302000
# timestep 303000
# timestep 304000
# timestep 305000
# timestep 306000
# timestep 307000
# timestep 308000
# timestep 309000
# timestep 310000
# timestep 311000
# timestep 312000
# timestep 313000
# timestep 314000
# timestep 315000
# timestep 316000
# timestep 317000
# timestep 318000

# %%
# Plot the performance of the agent 
plt.plot(r_sums)
plt.xlabel("Episode Number")
plt.ylabel("Reward")
# Out:
# Text(0, 0.5, 'Reward')

# %%
import pickle
# Store data (serialize)
with open('cartpole_DuelingDDQN_final.pickle', 'wb') as handle:
    pickle.dump(r_sums +[timestep,], handle)

# %%
with open('cartpole_DuelingDDQN_final.pickle', 'rb') as handle:
    b = pickle.load(handle)

# %%
print(len(b))
b[-1]
# Out:
# 2501
# 318949
